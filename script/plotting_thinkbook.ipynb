# %% [markdown]
# # Example plotting from the docs
# I use this script to plot data using python and to avoid learning how to MESA plotting system works.
#
# Installation for MESA reader can be found in the docs.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# import mesa_reader to make its classes accessible
import mesa_reader as mr

# %% [markdown]
# ## star_plus_point_mass

# %%
# NOTE: Edit the arguments to your location of the LOGS dir.
logs_dir1 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/star_plus_point_mass/LOGS1/'
logs_dir2 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/star_plus_point_mass/LOGS2/'

h1 = mr.MesaData(logs_dir1 + 'history.data') # Plotting history data
x1 = h1.star_age
y1 = h1.star_mass
plt.plot(x1, y1, label='star 1')

#h2 = mr.MesaData(logs_dir2 + 'history.data') # Plotting history data
#x2 = h2.star_age
#y2 = h2.star_mass
#plt.plot(x2, y2, label='star 2')

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 logs_dir1 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/star_plus_point_mass/LOGS1/'
#       3 logs_dir2 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/star_plus_point_mass/LOGS2/'
# ----> 5 h1 = mr.MesaData(logs_dir1 + 'history.data') # Plotting history data
#       6 x1 = h1.star_age
#       7 y1 = h1.star_mass
#
# File c:\Users\bvptr\anaconda3\envs\wpa\lib\site-packages\mesa_reader\__init__.py:129, in MesaData.__init__(self, file_name, file_type)
#     127 self.header_data = None
#     128 self.header_names = None
# --> 129 self.read_data()
#
# File c:\Users\bvptr\anaconda3\envs\wpa\lib\site-packages\mesa_reader\__init__.py:177, in MesaData.read_data(self)
#     175     self.read_model_data()
#     176 elif self.file_type == 'log':
# ...

# %% [markdown]
# ## star_plus_point_mass_explicit_mdot

# %%
# NOTE: Edit the arguments to your location of the LOGS dir.
logs_dir1 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/star_plus_point_mass_explicit_mdot/LOGS1/'
logs_dir2 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/star_plus_point_mass_explicit_mdot/LOGS2/'

h1 = mr.MesaData(logs_dir1 + 'history.data') # Plotting history data
x1 = h1.star_age
y1 = h1.star_mass
plt.plot(x1, y1, label='star 1')

#h2 = mr.MesaData(logs_dir2 + 'history.data') # Plotting history data
#x2 = h2.star_age
#y2 = h2.star_mass
#plt.plot(x2, y2, label='star 2')

plt.legend()

# %% [markdown]
# ## evolve_both_stars

# %%
# NOTE: Edit the arguments to your location of the LOGS dir.
logs_dir1 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/evolve_both_stars/LOGS1/'
logs_dir2 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/evolve_both_stars/LOGS2/'

h1 = mr.MesaData(logs_dir1 + 'history.data') # Plotting history data
x1 = h1.star_age
y1 = h1.star_mass
plt.plot(x1, y1, label='star 1')

h2 = mr.MesaData(logs_dir2 + 'history.data') # Plotting history data
x2 = h2.star_age
y2 = h2.star_mass
plt.plot(x2, y2, label='star 2')

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 logs_dir1 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/evolve_both_stars/LOGS1/'
#       3 logs_dir2 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/evolve_both_stars/LOGS2/'
# ----> 5 h1 = mr.MesaData(logs_dir1 + 'history.data') # Plotting history data
#       6 x1 = h1.star_age
#       7 y1 = h1.star_mass
#
# File c:\Users\bvptr\anaconda3\envs\wpa\lib\site-packages\mesa_reader\__init__.py:129, in MesaData.__init__(self, file_name, file_type)
#     127 self.header_data = None
#     128 self.header_names = None
# --> 129 self.read_data()
#
# File c:\Users\bvptr\anaconda3\envs\wpa\lib\site-packages\mesa_reader\__init__.py:177, in MesaData.read_data(self)
#     175     self.read_model_data()
#     176 elif self.file_type == 'log':
# ...

# %% [markdown]
# ## double_bh

# %%
# NOTE: Edit the arguments to your location of the LOGS dir.
logs_dir1 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/double_bh/LOGS1/'
logs_dir2 = '/home2/yousousen/software_etc/mesa/mesa-r22.11.1/binary/working_with_mesa/double_bh/LOGS2/'

h1 = mr.MesaData(logs_dir1 + 'history.data') # Plotting history data
x1 = h1.star_age
y1 = h1.star_mass
plt.plot(x1, y1, label='star 1')

h2 = mr.MesaData(logs_dir2 + 'history.data') # Plotting history data
x2 = h2.star_age
y2 = h2.star_mass
plt.plot(x2, y2, label='star 2')

plt.legend()

# %% [markdown]
# ## Iris

# %%
# NOTE: Edit the arguments to your location of the LOGS dir.
logs_dir1 = 'C:\\Users\\bvptr\\academia\\physics\\year3\\workshop_physics_and_astronomy\\wpa\\configuration_files\\binary\\iris\\LOGS1\\'
logs_dir2 = 'C:\\Users\\bvptr\\academia\\physics\\year3\\workshop_physics_and_astronomy\\wpa\\configuration_files\\binary\\iris\\LOGS2\\'
logs_binary_dir = 'C:\\Users\\bvptr\\academia\\physics\\year3\\workshop_physics_and_astronomy\\wpa\\configuration_files\\binary\\iris\\'

h1 = mr.MesaData(logs_dir1 + 'history.data') # Plotting history data
x1 = h1.model_number
y1 = h1.star_mass
plt.plot(x1, y1, label='star 1')

h2 = mr.MesaData(logs_dir2 + 'history.data') # Plotting history data
x2 = h2.model_number
y2 = h2.star_mass
plt.plot(x2, y2, label='star 2')

plt.legend()
plt.figure()

bh2 = mr.MesaData(logs_binary_dir + 'binary_history.data') # Plotting history data
plt.yticks(range(0,-100,-5))
plt.plot(h2.model_number, h2.lg_mtransfer_rate)

# %%
mass_transfer = 10 ** np.array(bh2.lg_mtransfer_rate)
star_mass_1 = np.array(h1.star_mass)
star_mass_2 = np.array(h2.star_mass)

print(len(mass_transfer))
print(len(star_mass_1))
# Out:
# 434
# 217

# %%
plt.plot(star_mass_1)
plt.plot(star_mass_2)
